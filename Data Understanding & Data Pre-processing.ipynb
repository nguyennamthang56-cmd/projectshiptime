# %%
# CELL 1: SETUP & IMPORT

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

file_path = "dynamic_supply_chain_logistics_dataset.csv"

df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
# CELL 2: DATA OVERVIEW

print("Shape of dataset:", df.shape)

print("\nColumn names:")
print(df.columns.tolist())

print("\nFirst 5 rows:")
display(df.head())

print("\nDataset information:")
df.info()

print("\nData types:")
print(df.dtypes)

print("\nDescriptive statistics:")
display(df.describe(include='all'))

print("\nMissing values:")
print(df.isnull().sum())

print("\nDuplicated rows:")
print(df.duplicated().sum())
# Out:
# Shape of dataset: (32065, 26)
#
# Column names:
# ['timestamp', 'vehicle_gps_latitude', 'vehicle_gps_longitude', 'fuel_consumption_rate', 'eta_variation_hours', 'traffic_congestion_level', 'warehouse_inventory_level', 'loading_unloading_time', 'handling_equipment_availability', 'order_fulfillment_status', 'weather_condition_severity', 'port_congestion_level', 'shipping_costs', 'supplier_reliability_score', 'lead_time_days', 'historical_demand', 'iot_temperature', 'cargo_condition_status', 'route_risk_level', 'customs_clearance_time', 'driver_behavior_score', 'fatigue_monitoring_score', 'disruption_likelihood_score', 'delay_probability', 'risk_classification', 'delivery_time_deviation']
#
# First 5 rows:
#              timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0  2021-01-01 00:00:00             40.375568             -77.014318
# 1  2021-01-01 01:00:00             33.507818            -117.036902
# 2  2021-01-01 02:00:00             30.020640             -75.269224
# ...

# %%
# CELL 3: DEFINE COLUMN TYPES

datetime_cols = ['timestamp']

categorical_cols = ['risk_classification']

target_col = 'delivery_time_deviation'

# Detect numerical columns automatically
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()

# Remove target column from numerical feature columns
if target_col in numerical_cols:
    numerical_cols.remove(target_col)

print("Datetime columns:", datetime_cols)
print("Categorical columns:", categorical_cols)
print("Numerical feature columns:", numerical_cols)
print("Target column:", target_col)
# Out:
# Datetime columns: ['timestamp']
# Categorical columns: ['risk_classification']
# Numerical feature columns: ['vehicle_gps_latitude', 'vehicle_gps_longitude', 'fuel_consumption_rate', 'eta_variation_hours', 'traffic_congestion_level', 'warehouse_inventory_level', 'loading_unloading_time', 'handling_equipment_availability', 'order_fulfillment_status', 'weather_condition_severity', 'port_congestion_level', 'shipping_costs', 'supplier_reliability_score', 'lead_time_days', 'historical_demand', 'iot_temperature', 'cargo_condition_status', 'route_risk_level', 'customs_clearance_time', 'driver_behavior_score', 'fatigue_monitoring_score', 'disruption_likelihood_score', 'delay_probability']
# Target column: delivery_time_deviation

# %%
# CELL 4: DATA TYPE CONVERSION
df['timestamp'] = pd.to_datetime(df['timestamp'], errors='coerce')

df['risk_classification'] = df['risk_classification'].astype('category')
numerical_cols = [
    'vehicle_gps_latitude', 'vehicle_gps_longitude', 'fuel_consumption_rate', 
    'eta_variation_hours', 'traffic_congestion_level', 'warehouse_inventory_level', 
    'loading_unloading_time', 'handling_equipment_availability', 'order_fulfillment_status', 
    'weather_condition_severity', 'port_congestion_level', 'shipping_costs', 
    'supplier_reliability_score', 'lead_time_days', 'historical_demand', 
    'iot_temperature', 'cargo_condition_status', 'route_risk_level', 
    'customs_clearance_time', 'driver_behavior_score', 'fatigue_monitoring_score', 
    'disruption_likelihood_score', 'delay_probability'
]

target_col = 'delivery_time_deviation'

for col in numerical_cols + [target_col]:
    df[col] = pd.to_numeric(df[col], errors='coerce')

print("Data types after conversion:")
print(df.dtypes)
# Out:
# Data types after conversion:
# timestamp                          datetime64[us]
# vehicle_gps_latitude                      float64
# vehicle_gps_longitude                     float64
# fuel_consumption_rate                     float64
# eta_variation_hours                       float64
# traffic_congestion_level                  float64
# warehouse_inventory_level                 float64
# loading_unloading_time                    float64
# handling_equipment_availability           float64
# order_fulfillment_status                  float64
# weather_condition_severity                float64
# port_congestion_level                     float64
# shipping_costs                            float64
# supplier_reliability_score                float64
# lead_time_days                            float64
# historical_demand                         float64
# iot_temperature                           float64
# cargo_condition_status                    float64
# ...

# %%
# CELL 5: TIME-BASED FEATURE ENGINEERING

df['hour_of_day'] = df['timestamp'].dt.hour
df['day_of_week'] = df['timestamp'].dt.day_name()
df['month'] = df['timestamp'].dt.month
df['year'] = df['timestamp'].dt.year
df['is_weekend'] = df['day_of_week'].isin(['Saturday', 'Sunday']).astype(int)

df['is_peak_hour'] = df['hour_of_day'].isin([7, 8, 9, 17, 18, 19]).astype(int)

display(df.head())
# Out:
#             timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0 2021-01-01 00:00:00             40.375568             -77.014318
# 1 2021-01-01 01:00:00             33.507818            -117.036902
# 2 2021-01-01 02:00:00             30.020640             -75.269224
# 3 2021-01-01 03:00:00             36.649223             -70.190529
# 4 2021-01-01 04:00:00             30.001279             -70.012195
#
#    fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0               5.136512             4.998009                  5.927586
# 1               5.101512             0.984929                  1.591992
# 2               5.090803             4.972665                  8.787765
# 3               8.219558             3.095064                  0.045257
# 4               5.000075             3.216077                  8.004851
#
#    warehouse_inventory_level  loading_unloading_time  \
# 0                 985.716862                4.951392
# ...

# %%
# CELL 6: MISSING VALUE ANALYSIS

missing_report = pd.DataFrame({
    'missing_count': df.isnull().sum(),
    'missing_percentage': df.isnull().mean() * 100
})

display(missing_report.sort_values(by='missing_percentage', ascending=False))
# Out:
#                                  missing_count  missing_percentage
# timestamp                                    0                 0.0
# vehicle_gps_latitude                         0                 0.0
# vehicle_gps_longitude                        0                 0.0
# fuel_consumption_rate                        0                 0.0
# eta_variation_hours                          0                 0.0
# traffic_congestion_level                     0                 0.0
# warehouse_inventory_level                    0                 0.0
# loading_unloading_time                       0                 0.0
# handling_equipment_availability              0                 0.0
# order_fulfillment_status                     0                 0.0
# weather_condition_severity                   0                 0.0
# port_congestion_level                        0                 0.0
# shipping_costs                               0                 0.0
# ...

# %%
# CELL 7: DUPLICATE CHECK

duplicate_count = df.duplicated().sum()

print("Number of duplicated rows:", duplicate_count)

if duplicate_count > 0:
    df = df.drop_duplicates()
    print("Duplicates removed.")
else:
    print("No duplicated rows found.")
# Out:
# Number of duplicated rows: 0
# No duplicated rows found.

# %%
# CELL 8: OUTLIER DETECTION USING IQR

def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    outliers = data[
        (data[column] < lower_bound) |
        (data[column] > upper_bound)
    ]
    
    return outliers, lower_bound, upper_bound

outlier_summary = []

for col in numerical_cols + [target_col]:
    outliers, lower, upper = detect_outliers_iqr(df, col)
    outlier_summary.append({
        'column': col,
        'outlier_count': len(outliers),
        'lower_bound': lower,
        'upper_bound': upper,
        'min_value': df[col].min(),
        'max_value': df[col].max()
    })

outlier_summary_df = pd.DataFrame(outlier_summary)
display(outlier_summary_df.sort_values(by='outlier_count', ascending=False))
# Out:
#                              column  outlier_count  lower_bound   upper_bound  \
# 2             fuel_consumption_rate           2536    -1.954956     16.644883
# 21      disruption_likelihood_score           2494     0.236229      1.456255
# 15                  iot_temperature           2301   -33.863704     29.956642
# 0              vehicle_gps_latitude              0    11.520892     64.213313
# 4          traffic_congestion_level              0    -9.115552     19.125174
# 5         warehouse_inventory_level              0  -770.767899   1327.417525
# 1             vehicle_gps_longitude              0  -156.015731    -23.317549
# 3               eta_variation_hours              0    -4.362173     10.432272
# 7   handling_equipment_availability              0    -0.787622      1.358326
# 6            loading_unloading_time              0    -3.664287      8.173273
# 10            port_congestion_level              0    -3.472502     17.824541
# ...

# %%
# CELL 9: BOXPLOT FOR TARGET VARIABLE

plt.figure(figsize=(8, 4))
sns.boxplot(x=df[target_col])
plt.title("Boxplot of Delivery Time Deviation")
plt.xlabel("Delivery Time Deviation")
plt.show()

# %%
# Boxplots for important numerical features

important_cols = [
    'fuel_consumption_rate',
    'traffic_congestion_level',
    'eta_variation_hours',
    'iot_temperature',
    'route_risk_level',
    'delay_probability',
    'delivery_time_deviation'
]

for col in important_cols:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
# CELL 10: OPTIONAL OUTLIER CAPPING FOR TARGET

outliers, lower, upper = detect_outliers_iqr(df, target_col)

df[target_col] = np.where(df[target_col] > upper, upper, df[target_col])
df[target_col] = np.where(df[target_col] < lower, lower, df[target_col])

print("Target outliers capped using IQR bounds.")
# Out:
# Target outliers capped using IQR bounds.

# %%
df['traffic_intensity_proxy'] = (
    df['traffic_congestion_level'] * df['is_peak_hour']
)

# %%
df['route_complexity'] = (
    df['traffic_congestion_level'] +
    df['route_risk_level'] +
    df['weather_condition_severity'] * 10
) / 3

# %%
df['lat_bin'] = pd.cut(df['vehicle_gps_latitude'], bins=5, labels=False)
df['long_bin'] = pd.cut(df['vehicle_gps_longitude'], bins=5, labels=False)

df['gps_zone'] = df['lat_bin'].astype(str) + "_" + df['long_bin'].astype(str)

# %%
zone_density = df['gps_zone'].value_counts().to_dict()

df['delivery_zone_density'] = df['gps_zone'].map(zone_density)

# %%
df['distance_proxy_x_peak_hour'] = df['eta_variation_hours'] * df['is_peak_hour']

df['traffic_x_weather'] = (
    df['traffic_congestion_level'] *
    df['weather_condition_severity']
)

df['traffic_x_route_risk'] = (
    df['traffic_congestion_level'] *
    df['route_risk_level']
)

# %%
# CELL 11: EXPORT CLEANED DATASET

df.to_csv("cleaned_dynamic_supply_chain_logistics_dataset.csv", index=False)

print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS (EDA)

# %% [markdown]
# ### Task 1: Distribution of target variable
# Analyzing the distribution of the target variable `delivery_time_deviation`.

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['delivery_time_deviation'], kde=True, color='#2b5c8f', bins=30)
plt.title('Distribution of Delivery Time Deviation (Target Variable)', fontsize=14, fontweight='bold')
plt.xlabel('Delivery Time Deviation')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Task 2: Distribution of numerical features
# Checking the distribution of representative numerical features within the logistics dataset.

# %%
num_features = ['fuel_consumption_rate', 'eta_variation_hours', 'warehouse_inventory_level', 'shipping_costs']
fig, axes = plt.subplots(2, 2, figsize=(14, 10))
for i, col in enumerate(num_features):
    ax = axes[i//2, i%2]
    sns.histplot(df[col], kde=True, ax=ax, color='#1e847f', bins=30)
    ax.set_title(f'Distribution of {col}', fontsize=12, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 3: Countplot of risk classification
# Visualizing the frequencies of orders/trips grouped by their risk classification levels.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(
    x='risk_classification', 
    data=df, 
    order=df['risk_classification'].value_counts().index, 
    hue='risk_classification', 
    palette='Set2', 
    legend=False
)
plt.title('Countplot of Risk Classification', fontsize=14, fontweight='bold')
plt.xlabel('Risk Classification')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Task 4: Correlation heatmap
# Plotting the correlation matrix between the target variable and environmental metrics.

# %%
plt.figure(figsize=(11, 9))
corr_cols = ['delivery_time_deviation', 'delay_probability', 'traffic_congestion_level', 
             'fuel_consumption_rate', 'eta_variation_hours', 'shipping_costs', 'customs_clearance_time']
corr_matrix = df[corr_cols].corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5, vmin=-1, vmax=1)
plt.title('Correlation Heatmap of Key Features', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Task 5: Scatter plot: delay_probability vs target
# Examining the relationship between Delay Probability (`delay_probability`) and Delivery Time Deviation (`delivery_time_deviation`).

# %%
plt.figure(figsize=(9, 6))
sns.scatterplot(x='delay_probability', y='delivery_time_deviation', data=df, alpha=0.5, color='#6f42c1')
plt.title('Scatter Plot: Delay Probability vs Target', fontsize=14, fontweight='bold')
plt.xlabel('Delay Probability')
plt.ylabel('Delivery Time Deviation (Target)')
plt.show()

# %% [markdown]
# ### Task 6: Scatter plot: traffic_congestion_level vs target
# Examining the relationship between Traffic Congestion Level (`traffic_congestion_level`) and Delivery Time Deviation (`delivery_time_deviation`).

# %%
plt.figure(figsize=(9, 6))
sns.scatterplot(x='traffic_congestion_level', y='delivery_time_deviation', data=df, alpha=0.5, color='#d9534f')
plt.title('Scatter Plot: Traffic Congestion Level vs Target', fontsize=14, fontweight='bold')
plt.xlabel('Traffic Congestion Level')
plt.ylabel('Delivery Time Deviation (Target)')
plt.show()

# %% [markdown]
# ### Task 7: Boxplot: risk_classification vs target
# Comparing the distributions and variation of the target variable across different risk classification groups.

# %%
plt.figure(figsize=(9, 6))
sns.boxplot(
    x='risk_classification', 
    y='delivery_time_deviation', 
    data=df, 
    hue='risk_classification', 
    palette='Pastel1', 
    legend=False
)
plt.title('Boxplot: Risk Classification vs Target', fontsize=14, fontweight='bold')
plt.xlabel('Risk Classification')
plt.ylabel('Delivery Time Deviation (Target)')
plt.show()

# %% [markdown]
# ### Task 8: Analysis by peak hour
# Dissecting and comparing the operational impact of rush hour windows (Morning Peak, Evening Peak) on the target variable.

# %%
df['hour'] = df['timestamp'].dt.hour
df['peak_hour_type'] = 'Normal Hours'
df.loc[(df['hour'] >= 6) & (df['hour'] <= 9), 'peak_hour_type'] = 'Morning Peak (6h-9h)'
df.loc[(df['hour'] >= 16) & (df['hour'] <= 19), 'peak_hour_type'] = 'Evening Peak (16h-19h)'

plt.figure(figsize=(10, 6))
sns.boxplot(
    x='peak_hour_type', 
    y='delivery_time_deviation', 
    data=df, 
    hue='peak_hour_type', 
    palette='pastel', 
    legend=False
)
plt.title('Delivery Time Deviation Analysis by Peak Hour Type', fontsize=14, fontweight='bold')
plt.xlabel('Time Period')
plt.ylabel('Delivery Time Deviation (Target)')
plt.show()

# %% [markdown]
# ### Conclusion & Key Insights Summary
# 1. **Wide Distribution of Target Variable:** The dispersion of `delivery_time_deviation` highlights high operational uncertainty in the supply chain flow.
# 2. **Dominant Influencing Factors:** The correlation matrix reveals that `delay_probability` and `traffic_congestion_level` strongly dictate delivery delays.
# 3. **Risk Classification Integrity:** The *High Risk* tier demonstrates a significantly wider positive spread (prolonged delays) compared to *Low Risk*.
# 4. **Evening Peak Hour Pressure:** Trips initiated or active during `Evening Peak (16h-19h)` endure broader deviation spreads, resulting in the most unpredictable delivery delays.
